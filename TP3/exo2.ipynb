# %% [markdown]
# # TP3 EXO 2

# %% [markdown]
# # 1 Theorie
# Soit 𝑋~𝐺𝑒𝑜(𝜆) et 𝑌~𝐺𝑒𝑜(𝜇) deux variables aléatoires indépendantes. La variable aléatoire 𝑍 = min(𝑋, 𝑌) suit également une loi géométrique de paramètre 𝑝 que l’on exprimera en fonction de
# 𝜆 et u

# %% [markdown]
# # 2 Simulation

# %% [markdown]
# Simulation de la loi 𝑋~𝐺𝑒𝑜(𝜆) avec 𝜆 = 0.3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import gamma

# theorie
lambda_x = 0.3  

# loi geometrique X
k = np.arange(1, 15)
geoX =  (1-lambda_x)**(k-1)*lambda_x     
plt.bar(k, geoX, color="red", label="Théorique loi de poisson")

# experimentation
essais = 100
expX =[]
for i in range(essais) :
    cpt = 0
    while np.random.rand() > lambda_x : 
        cpt += 1
    if cpt == 0 :
        cpt = 1
    expX.append(cpt)
    
    
def LoiBernoulli(p) :
    num = np.random.rand()
    if num < p :
        return 1 # succès
    else :
        return 0 # échec

def LoiGeometrique(p) :
    events = 0
    while True :
        if LoiBernoulli(p) == 1 :
            events += 1
            break
        else : 
            events += 1
    return events

plt.hist(expX, bins=np.arange(1, 5) - 0.5, density = True, alpha = 0.6, label="Empirique") 
plt.legend()
plt.show()

# %% [markdown]
# Simulation de 𝑌~𝐺𝑒𝑜(𝜇)

# %%
# theorie
micro_y = 0.5 

# loi geometrique X
k = np.arange(1, 15)
geoY =  (1-micro_y)**(k-1)*micro_y      
plt.bar(k, geoY, color="red", label="Théorique loi de poisson")

# experimentation
essais = 100
expY =[]
for i in range(essais) :
    cpt = 0
    while np.random.rand() > micro_y : 
        cpt += 1
    if cpt == 0 :
        cpt = 1;
    expY.append(cpt)
plt.hist(expY, bins=np.arange(1, 5) - 0.5, density = True, alpha = 0.6, label="Empirique") 
plt.legend()
plt.show()

# %% [markdown]
# Simulation de 𝑍 = min(𝑋, 𝑌)

# %%
# theorie
p_z =  

# loi geometrique X
k = np.arange(1, 15)
geoZ =  (1-p_z)**(k-1)*p_z      # gamma factoriel
plt.bar(k, geoZ, color="red", label="Théorique loi de poisson")

# experimentation
essais = 100
expZ =[]
for i in range(essais) :
    cpt = 0
    while np.random.rand() > p_z : 
        cpt += 1
    if cpt == 0 :
        cpt = 1;
    expZ.append(cpt)
plt.hist(expZ, bins=np.arange(1, 5) - 0.5, density = True, alpha = 0.6, label="Empirique") 
plt.legend()
plt.show()
# Out:
#   Cell In[22], line 2
#     lambda_z =
#                 ^
# SyntaxError: invalid syntax
